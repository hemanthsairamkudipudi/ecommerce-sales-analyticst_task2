# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('../Data/processed/cleaned_ecommerce_sales.csv')

df.head()
# Out:
#    order_id  order_date  customer_id product_category region  quantity  \
# 0     10001  2022-01-01         1102           Beauty  South         7
# 1     10002  2022-01-02         1435         Clothing  South         7
# 2     10003  2022-01-03         1860           Beauty   East         3
# 3     10004  2022-01-04         1270      Electronics   West         5
# 4     10005  2022-01-05         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            Cod              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue  order_year  order_month order_month_name  order_day
# 0  1883.20        2022            1          January          1
# 1   304.10        2022            1          January          2
# 2   644.35        2022            1          January          3
# 3  2569.90        2022            1          January          4
# 4   468.56        2022            1          January          5

# %%
print("Rows and columns:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Rows and columns: (5000, 16)
#
# Columns:
# ['order_id', 'order_date', 'customer_id', 'product_category', 'region', 'quantity', 'unit_price', 'discount', 'payment_method', 'delivery_days', 'customer_rating', 'revenue', 'order_year', 'order_month', 'order_month_name', 'order_day']
#
# Missing values:
# order_id            0
# order_date          0
# customer_id         0
# product_category    0
# region              0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# delivery_days       0
# customer_rating     0
# revenue             0
# order_year          0
# order_month         0
# order_month_name    0
# order_day           0
# dtype: int64

# %%
conn = sqlite3.connect('../Data/ecommerce.db')

# %%
tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)

tables
# Out:
#               name
# 0  ecommerce_sales

# %%
df.to_sql(
    'ecommerce_sales',
    conn,
    index=False,
    if_exists='replace'
)
# Out:
# 5000

# %%
pd.read_sql_query(
    "SELECT * FROM ecommerce_sales LIMIT 5;",
    conn
)
# Out:
#    order_id  order_date  customer_id product_category region  quantity  \
# 0     10001  2022-01-01         1102           Beauty  South         7
# 1     10002  2022-01-02         1435         Clothing  South         7
# 2     10003  2022-01-03         1860           Beauty   East         3
# 3     10004  2022-01-04         1270      Electronics   West         5
# 4     10005  2022-01-05         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            Cod              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue  order_year  order_month order_month_name  order_day
# 0  1883.20        2022            1          January          1
# 1   304.10        2022            1          January          2
# 2   644.35        2022            1          January          3
# 3  2569.90        2022            1          January          4
# 4   468.56        2022            1          January          5

# %%
query = """
SELECT *
FROM ecommerce_sales
LIMIT 10;
"""

pd.read_sql_query(query, conn)
# Out:
#    order_id  order_date  customer_id product_category region  quantity  \
# 0     10001  2022-01-01         1102           Beauty  South         7
# 1     10002  2022-01-02         1435         Clothing  South         7
# 2     10003  2022-01-03         1860           Beauty   East         3
# 3     10004  2022-01-04         1270      Electronics   West         5
# 4     10005  2022-01-05         1106         Clothing   West         5
# 5     10006  2022-01-06         1071      Electronics   West         2
# 6     10007  2022-01-07         1700         Clothing  South         6
# 7     10008  2022-01-08         1020           Beauty  North         6
# 8     10009  2022-01-09         1614         Clothing  South         6
# 9     10010  2022-01-10         1121         Clothing   West         4
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            Cod              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
# 5      264.44      0.20           Card              3              3.3
# 6      564.60      0.23           Card              1              1.8
# 7      265.71      0.13           Card              2              3.7
# 8      224.65      0.27           Card              2              1.4
# 9      272.71      0.06           Card             10              4.5
#
#    revenue  order_year  order_month order_month_name  order_day
# 0  1883.20        2022            1          January          1
# 1   304.10        2022            1          January          2
# 2   644.35        2022            1          January          3
# 3  2569.90        2022            1          January          4
# 4   468.56        2022            1          January          5
# 5   423.10        2022            1          January          6
# 6  2608.45        2022            1          January          7
# 7  1387.01        2022            1          January          8
# 8   983.97        2022            1          January          9
# 9  1025.39        2022            1          January         10

# %%
query = """
SELECT COUNT(*) AS total_orders
FROM ecommerce_sales;
"""

pd.read_sql_query(query, conn)
# Out:
#    total_orders
# 0          5000
